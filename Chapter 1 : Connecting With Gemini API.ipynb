# %%
# Conneting with Gemini API

# %%
from google import genai
from google.genai import types

# Developer TODO: Replace YOUR_API_KEY with your API key.
API_KEY = "AQ.Ab8RN6KpnPj4RLwF6qPp9n7feuvIkuAZbwkmNJfGCwJpccYHKQ"

client = genai.Client(
    vertexai=True, api_key=API_KEY
)

# %%
import os

os.environ["GEMINI_API_KEY"] = "AQ.Ab8RN6KpnPj4RLwF6qPp9n7feuvIkuAZbwkmNJfGCwJpccYHKQ"

# %%
# Checking if API is working or not

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain money laundering in simple terms."
)

print(response.text)
# Out:
# Imagine you have money from illegal activities, like selling drugs or committing fraud. This money is "dirty" because its origin is a crime, and you can't just go spend large amounts of it without attracting suspicion from banks or the police.
#
# **Money laundering is the process of making that "dirty" money look "clean" or legitimate.** It's like putting dirty clothes in a washing machine so they come out looking fresh and new.
#
# Here's how it generally works in three main steps:
#
# 1.  **Placement (Getting it In):**
#     *   This is where the criminals try to get their "dirty" cash into the legitimate financial system for the first time.
#     *   **Example:** They might break up large sums of cash into many smaller deposits (to avoid detection thresholds), deposit it into a bank account, buy assets like cars or gambling chips, or sneak it into a cash-heavy business they own (like a restaurant or car wash) and claim it as legitimate sales.
#
# ...

# %%
chat = client.chats.create(model="gemini-2.5-flash")

# %%
response_1 = chat.send_message("Explain what a suspicious transaction is in AML.")

print(response_1.text)
# Out:
# In Anti-Money Laundering (AML), a **suspicious transaction** is any financial transaction or activity that lacks a clear economic or lawful purpose, appears to be unusual given the customer's profile or typical business activities, or seems to be designed to evade reporting requirements or disguise the true nature, source, ownership, or control of funds.
#
# It's important to note that a suspicious transaction doesn't necessarily mean a crime has *already* been committed, but rather that there are **reasonable grounds to suspect** it *could* be related to illegal activities like money laundering, terrorist financing, fraud, or other financial crimes.
#
# Here's a breakdown of what constitutes a suspicious transaction and its key characteristics:
#
# 1.  **Deviation from Norm:**
# ...
